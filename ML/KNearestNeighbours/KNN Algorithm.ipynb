# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
dfx=pd.read_csv('../Datasets/xdata.csv')
dfy=pd.read_csv('../Datasets/ydata.csv')

# %%
X=dfx.values
Y=dfy.values
print(type(X))
# Out:
# <class 'numpy.ndarray'>

# %%
print(X.shape,Y.shape)
# Out:
# (399, 3) (399, 2)

# %%
#print(X)

# %%
#print(Y)

# %%
#drop first column in both X and Y
#->bcz it is just serial no, not a feature

# %%
X=X[:,1:]
Y=Y[:,1:].reshape((-1,))
print(X.shape,Y.shape)
# Out:
# (399, 2) (399,)

# %%
#in reshape function, the use of -1 is to make the order acc. to any value
#row is fixed, col=-1, adjust values in col

# %%
#print(Y)

# %%
plt.style.use('seaborn')
plt.scatter(X[:,0],X[:,1],c=Y)

# %%
plt.style.use('seaborn')
plt.scatter(X[:,0],X[:,1],c=Y)

querypoint=[1.7,2.9]
plt.scatter(querypoint[0],querypoint[1],color='red')

# %%
#Euclidean distance is used

# %%
def dist(x1,x2):
    return np.sqrt((sum(x2-x1)**2))

#here x1 and x2 are vectors like [1,4,5] and [8,2,1]
#so, this function will work for any dimension

def knn(X,Y,queryPoint,k=5):
    vals=[]
    m=X.shape[0]
    
    for i in range(m):
        d=dist(queryPoint,X[i])
        vals.append((d,Y[i]))
        
    vals=sorted(vals)    
    #Nearest/ First K points
    vals=vals[:k]
    vals=np.array(vals)
    
    #print(vals)
    
    new_vals=np.unique(vals[:,1],return_counts=True)
    #print(new_vals)
    
    #gives the key corresponding to max freq->argmax()
    index=new_vals[1].argmax()
    pred=new_vals[0][index]

    return pred

# %%
x=knn(X,Y,querypoint)
print(x)
# Out:
# 0.0

# %%
x=knn(X,Y,[4,5])
print(x)
# Out:
# 0.0

# %%
x=knn(X,Y,[2,2])
print(x)
# Out:
# 1.0
