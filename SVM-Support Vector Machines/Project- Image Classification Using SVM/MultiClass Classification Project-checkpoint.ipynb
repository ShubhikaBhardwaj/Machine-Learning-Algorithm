# %% [markdown]
# # Dataset Preparation

# %%
import numpy as np
import os
#import matplotlib.pyplot as plt
from pathlib import Path
from keras.preprocessing import image
# Out:
# Using TensorFlow backend.

# %%
p=Path("../../Datasets/Images/images")
type(p)
# Out:
# pathlib.WindowsPath

# %%
dirs = p.glob("*")

labels_dict = {"cat":0,"dog":1,"horse":2,"human":3}

image_data = []
labels = []

for folder_dir in dirs:
    #print(folder_name)
    label = str(folder_dir).split("\\")[-1][:-1]
    
    
    for img_path in folder_dir.glob("*.jpg"):
        img = image.load_img(img_path,target_size=(32,32))
        img_array = image.img_to_array(img)
        image_data.append(img_array)
        labels.append(labels_dict[label])

# %%
print(len(labels))
print(len(image_data))
# Out:
# 808
# 808

# %%
#print(labels)

# %%
# Convert this into numpy array
image_data = np.array(image_data,dtype='float32')/255.0
labels = np.array(labels)

print(image_data.shape,labels.shape)
# Out:
# (808, 32, 32, 3) (808,)

# %% [markdown]
# ## Randomly Shuffle the Data!

# %%
import random

combined=list(zip(image_data,labels))
random.shuffle(combined)

#Unzip
image_data[:],labels[:]=zip(*combined)

## * ->Star symbol is used to unzip the data

# %% [markdown]
# ## Visualise the data!

# %%
def drawImg(img):
    import matplotlib.pyplot as plt
    plt.imshow(img)
    plt.axis("off")
    plt.show()
    return 

for i in range(10):
    drawImg(image_data[i])

# %% [markdown]
# ## SVM Classifier

# %%
class SVM:
    
    def __init__(self,C=1.0):
        self.C = C
        self.W = 0
        self.b = 0
        
    def hingeLoss(self,W,b,X,Y):
        loss  = 0.0
        
        loss += .5*np.dot(W,W.T)
        m = X.shape[0]
        
        for i in range(m):
            ti = Y[i]*(np.dot(W,X[i].T)+b)
            #print(ti)
            loss[0][0] += self.C *max(0,(1-ti))
                        
        return loss[0][0]
    
    def fit(self,X,Y,batch_size=100,learning_rate=0.001,maxItr=300):
        
        no_of_features = X.shape[1]
        no_of_samples = X.shape[0]
        
        n = learning_rate
        c = self.C
        
        #Init the model parameters
        W = np.zeros((1,no_of_features))
        bias = 0
        
        #Initial Loss
        
        #Training from here...
        # Weight and Bias update rule that we discussed!
        losses = []
        
        for i in range(maxItr):
            #Training Loop
            
            l = self.hingeLoss(W,bias,X,Y)
            losses.append(l)
            ids = np.arange(no_of_samples)
            np.random.shuffle(ids)
            
            #Batch Gradient Descent(Paper) with random shuffling
            for batch_start in range(0,no_of_samples,batch_size):
                #Assume 0 gradient for the batch
                gradw = 0
                gradb = 0
                
                #Iterate over all examples in the mini batch
                for j in range(batch_start,batch_start+batch_size):
                    if j<no_of_samples:
                        i = ids[j]
                        ti =  Y[i]*(np.dot(W,X[i].T)+bias)
                        
                        if ti>1:
                            gradw += 0
                            gradb += 0
                        else:
                            gradw += c*Y[i]*X[i]
                            gradb += c*Y[i]
                            
                #Gradient for the batch is ready! Update W,B
                W = W - n*W + n*gradw
                bias = bias + n*gradb
                
        
        self.W = W
        self.b = bias
        return W,bias,losses

# %% [markdown]
# ## Convert data for One VS One Classifier

# %%
M= image_data.shape[0]
image_data=image_data.reshape(M,-1)


print(image_data.shape)
print(labels.shape)
# Out:
# (808, 3072)
# (808,)

# %%
classes=len(np.unique(labels))
print(classes)
# Out:
# 4

# %%
def classWisedata(x,y):
    data={}
    
    for i in range(classes):
        data[i]=[]
        
    for i in range(x.shape[0]):
        data[y[i]].append(x[i])
        
    for k in data.keys():
        data[k]=np.array(data[k])
        
    return data

# %%
data=classWisedata(image_data,labels)

# %%
print(data[0].shape[0])
print(data[1].shape[0])
print(data[2].shape[0])
print(data[3].shape[0])

#202 images for every class in the dataset
# Out:
# 202
# 202
# 202
# 202

# %%
print(data[0].shape)   #3072 features are present
# Out:
# (202, 3072)

# %%
def getDataPairForSVM(d1,d2):
    
    #Combining the data for 2 classes in one data structure
    #labels are -1 and +1 respectively
    l1,l2=d1.shape[0],d2.shape[0]
    
    samples=l1+l2
    features=d1.shape[1]
    
    data_pair=np.zeros((samples,features))
    data_labels=np.zeros((samples,features))
    
    data_pair[:l1,:]=d1
    data_pair[l1:,:]=d2
    
    data_labels[:l1,:]=-1
    data_labels[l1:,:]=+1
    
    return data_pair,data_labels

# %% [markdown]
# ## Training NC2 SVM's Classifier

# %%
mySVM=SVM()

# %%
def trainSVMs(x,y):
    
    svm_classifiers={}
    for i in range(classes):
        svm_classifiers[i]={}
        for j in range(i+1,classes):
            xpair,ypair= getDataPairForSVM(data[i],data[j])
            loss=[]
            wts,b,loss=mySVM.fit(xpair,ypair)   #,learning_rate=0.00001,maxItr=1000)
            svm_classifiers[i][j]=(wts,b)
            
            #plt.plot(loss)
            #plt.show()
            
    return svm_classifiers

# %%
svm_classifiers=trainSVMs(image_data,labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-fd6b2837987a> in <module>
# ----> 1 svm_classifiers=trainSVMs(image_data,labels)
#
# <ipython-input-29-f5984c73861a> in trainSVMs(x, y)
#       7             xpair,ypair= getDataPairForSVM(data[i],data[j])
#       8             loss=[]
# ----> 9             wts,b,loss=mySVM.fit(xpair,ypair)   #,learning_rate=0.00001,maxItr=1000)
#      10             svm_classifiers[i][j]=(wts,b)
#      11
#
# <ipython-input-20-4408434684f1> in fit(self, X, Y, batch_size, learning_rate, maxItr)
#      40             #Training Loop
#      41
# ---> 42             l = self.hingeLoss(W,bias,X,Y)
#      43             losses.append(l)
#      44             ids = np.arange(no_of_samples)
#
# <ipython-input-20-4408434684f1> in hingeLoss(self, W, b, X, Y)
#      15             ti = Y[i]*(np.dot(W,X[i].T)+b)
# ...
